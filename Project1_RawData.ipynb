# %%
import pandas as pd
df = pd.read_csv("Argentina.csv")

# Add a column with a fixed value
df["País"] = "Argentina"

# Save it back
df.to_csv("Argentina.csv", index=False)

# %%
df
# Out:
#                 Page ID                          Page name  \
# 0       301506776559902                Gobierno de Córdoba
# 1       469950659541311                      Ratio oficial
# 2       168244566381059  Jefatura de Gabinete de Ministros
# 3          130929705668           Municipalidad de Córdoba
# 4       443075912216987     Alianza La Libertad Avanza PBA
# ...                 ...                                ...
# 52093   106236511982693                   qcsf_rik_guitare
# 52094   109038637276449                Roukayatou officiel
# 52095   102538795925802                      Solo_tech_VPN
# 52096  1645257202450768                       Jacob Humber
# 52097   121436347712988               tecnologistica_latam
#
#                                Disclaimer Amount spent (ARS)  \
# 0                     Gobierno de Córdoba         1452528035
# 1                           Ratio oficial         1228317919
# 2       Jefatura de Gabinete de Ministros         1090958630
# ...

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Argentina\Completo_ARG
#
# 16/06/2026  19:54    <DIR>          .
# 16/06/2026  16:11    <DIR>          ..
# 16/06/2026  19:44    <DIR>          .ipynb_checkpoints
# 16/06/2026  19:46         4.432.416 Argentina.csv
# 16/06/2026  16:11               555 FacebookAdLibraryReport_2026-06-13_AR_lifelong_locations.csv
# 16/06/2026  16:11             2.105 README.txt
# 16/06/2026  16:11    <DIR>          regions
# 16/06/2026  19:54            19.832 Untitled.ipynb
#                4 archivos      4.454.908 bytes
#                4 dirs  202.951.708.672 bytes libres

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Argentina

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1
#
# 16/06/2026  19:41    <DIR>          .
# 16/06/2026  15:34    <DIR>          ..
# 16/06/2026  16:11    <DIR>          Argentina
# 16/06/2026  19:11    <DIR>          Bolivia
# 16/06/2026  18:34    <DIR>          Brazil
# 16/06/2026  19:00    <DIR>          Chile
# 16/06/2026  19:13    <DIR>          Colombia
# 16/06/2026  19:15    <DIR>          Ecuador
# 16/06/2026  19:35    <DIR>          Guyana
# 16/06/2026  18:53    <DIR>          Paraguay
# 16/06/2026  19:03    <DIR>          Per£
# 16/06/2026  19:41    <DIR>          Surinam
# 16/06/2026  18:45    <DIR>          Uruguay
# 16/06/2026  19:17    <DIR>          Venezuela
#                0 archivos              0 bytes
#               14 dirs  202.946.715.648 bytes libres

# %%
cd Bolivia
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Bolivia

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Bolivia
#
# 16/06/2026  19:11    <DIR>          .
# 16/06/2026  19:41    <DIR>          ..
# 16/06/2026  19:54    <DIR>          Completo
#                0 archivos              0 bytes
#                3 dirs  202.946.711.552 bytes libres

# %%
cd Completo
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Bolivia\Completo

# %%
import pandas as pd
df = pd.read_csv("Bolivia.csv")

# Add a column with a fixed value
df["País"] = "Bolivia"

# Save it back
df.to_csv("Bolivia.csv", index=False)
df
# Out:
#                 Page ID                                    Page name  \
# 0          128123870725                          Samuel Doria Medina
# 1       373759069434274                   Jorge Tuto Quiroga Ramirez
# 2       130336323685885                    Gobernación de Santa Cruz
# 3       102674511293040                          Manfred Reyes Villa
# 4       111268350662015                                   JP Velasco
# ...                 ...                                          ...
# 14861   805828955942639                              Copa Collection
# 14862   102852888791843                       Espíritu de Billonario
# 14863  1408474549421296  IFE Conference del Tecnológico de Monterrey
# 14864   107143005565062                                      Stip_04
# 14865   100401512487804                                          666
#
#                                Disclaimer Amount spent (BOB)  \
# 0                     Samuel Doria Medina            1949741
# ...

# %%
cd..
# Out:
#   Cell In[17], line 1
#     cd..
#        ^
# SyntaxError: invalid syntax

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Bolivia

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1
#
# 16/06/2026  19:41    <DIR>          .
# 16/06/2026  15:34    <DIR>          ..
# 16/06/2026  16:11    <DIR>          Argentina
# 16/06/2026  19:11    <DIR>          Bolivia
# 16/06/2026  18:34    <DIR>          Brazil
# 16/06/2026  19:00    <DIR>          Chile
# 16/06/2026  19:13    <DIR>          Colombia
# 16/06/2026  19:15    <DIR>          Ecuador
# 16/06/2026  19:35    <DIR>          Guyana
# 16/06/2026  18:53    <DIR>          Paraguay
# 16/06/2026  19:03    <DIR>          Per£
# 16/06/2026  19:41    <DIR>          Surinam
# 16/06/2026  18:45    <DIR>          Uruguay
# 16/06/2026  19:17    <DIR>          Venezuela
#                0 archivos              0 bytes
#               14 dirs  202.735.980.544 bytes libres

# %%
cd Brazil
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Brazil

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Brazil
#
# 16/06/2026  18:34    <DIR>          .
# 16/06/2026  19:41    <DIR>          ..
# 16/06/2026  19:50    <DIR>          Completo
# 16/06/2026  18:33    <DIR>          Los3_BRA
#                0 archivos              0 bytes
#                4 dirs  202.733.129.728 bytes libres

# %%
cd Completo
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Brazil\Completo

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Brazil\Completo
#
# 16/06/2026  19:50    <DIR>          .
# 16/06/2026  18:34    <DIR>          ..
# 16/06/2026  18:37        27.399.656 Brazil.csv
# 16/06/2026  18:37               608 FacebookAdLibraryReport_2026-06-13_BR_lifelong_locations.csv
# 16/06/2026  18:37             2.105 README.txt
# 16/06/2026  18:37    <DIR>          regions
#                3 archivos     27.402.369 bytes
#                3 dirs  203.128.217.600 bytes libres

# %%
import pandas as pd
df = pd.read_csv("Brazil.csv")

# Add a column with a fixed value
df["País"] = "Brazil"

# Save it back
df.to_csv("Brazil.csv", index=False)
df
# Out:
# C:\Users\igrimaldi\AppData\Local\Temp\ipykernel_7336\2972499053.py:2: DtypeWarning: Columns (0: Amount spent (BRL)) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Brazil.csv")
#                  Page ID                       Page name  \
# 0       1894520370802455               Governo do Brasil
# 1        301774903545521                 Brasil Paralelo
# 2       1894520370802455               Governo do Brasil
# 3        101189854802059                   Revista Oeste
# 4        105821366170914  PT - Partido dos Trabalhadores
# ...                  ...                             ...
# 358726   109633095368358             lucidlinesclothing_
# 358727   304719359556549                           Wires
# 358728      190382688990       Alex Galmeanu Photography
# 358729   104484765775064                    tommyvext2.0
# 358730   309797769928675             Devils Dance Studio
#
# ...

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Brazil

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1
#
# 16/06/2026  19:41    <DIR>          .
# 16/06/2026  15:34    <DIR>          ..
# 16/06/2026  16:11    <DIR>          Argentina
# 16/06/2026  19:11    <DIR>          Bolivia
# 16/06/2026  18:34    <DIR>          Brazil
# 16/06/2026  19:00    <DIR>          Chile
# 16/06/2026  19:13    <DIR>          Colombia
# 16/06/2026  19:15    <DIR>          Ecuador
# 16/06/2026  19:35    <DIR>          Guyana
# 16/06/2026  18:53    <DIR>          Paraguay
# 16/06/2026  19:03    <DIR>          Per£
# 16/06/2026  19:41    <DIR>          Surinam
# 16/06/2026  18:45    <DIR>          Uruguay
# 16/06/2026  19:17    <DIR>          Venezuela
#                0 archivos              0 bytes
#               14 dirs  203.118.776.320 bytes libres

# %%
cd Chile
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Chile

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Chile
#
# 16/06/2026  19:00    <DIR>          .
# 16/06/2026  19:41    <DIR>          ..
# 16/06/2026  19:50    <DIR>          Completo
#                0 archivos              0 bytes
#                3 dirs  203.118.759.936 bytes libres

# %%
cd Completo
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Chile\Completo

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Chile\Completo
#
# 16/06/2026  19:50    <DIR>          .
# 16/06/2026  19:00    <DIR>          ..
# 16/06/2026  19:00         2.956.616 Chile.csv
# 16/06/2026  19:00               502 FacebookAdLibraryReport_2026-06-13_CL_lifelong_locations.csv
# 16/06/2026  19:00             2.105 README.txt
# 16/06/2026  19:00    <DIR>          regions
#                3 archivos      2.959.223 bytes
#                3 dirs  203.118.747.648 bytes libres

# %%
import pandas as pd
df = pd.read_csv("Chile.csv")

# Add a column with a fixed value
df["País"] = "Chile"

# Save it back
df.to_csv("Chile.csv", index=False)
df
# Out:
#                 Page ID            Page name  \
# 0      1366892303449939  Partido Republicano
# 1       881095048648989    José Antonio Kast
# 2      1548643738480723  Asistencia Deudores
# 3           78617029137     Greenpeace Chile
# 4           10192152668  Renovación Nacional
# ...                 ...                  ...
# 37909   101107716085656            BadPage04
# 37910   117222171476042  Learning is the key
# 37911   105077014711300             Wasenara
# 37912   126334398764021           moha_el_az
# 37913   369325156488153          Ubuntu Life
#
#                                Disclaimer Amount spent (CLP)  \
# 0                     Partido Republicano          694488783
# 1                       José Antonio Kast          485558232
# 2                     Asistencia Deudores          239797327
# 3       Fundación Greenpeace Pacífico Sur          237622553
# 4                     Renovación Nacional          237414238
# ...

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Chile

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1
#
# 16/06/2026  19:41    <DIR>          .
# 16/06/2026  15:34    <DIR>          ..
# 16/06/2026  16:11    <DIR>          Argentina
# 16/06/2026  19:11    <DIR>          Bolivia
# 16/06/2026  18:34    <DIR>          Brazil
# 16/06/2026  19:00    <DIR>          Chile
# 16/06/2026  19:13    <DIR>          Colombia
# 16/06/2026  19:15    <DIR>          Ecuador
# 16/06/2026  19:35    <DIR>          Guyana
# 16/06/2026  18:53    <DIR>          Paraguay
# 16/06/2026  19:03    <DIR>          Per£
# 16/06/2026  19:41    <DIR>          Surinam
# 16/06/2026  18:45    <DIR>          Uruguay
# 16/06/2026  19:17    <DIR>          Venezuela
#                0 archivos              0 bytes
#               14 dirs  203.099.201.536 bytes libres

# %%
cd Colombia
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Colombia

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Colombia
#
# 16/06/2026  19:13    <DIR>          .
# 16/06/2026  19:41    <DIR>          ..
# 16/06/2026  19:50    <DIR>          Completo
#                0 archivos              0 bytes
#                3 dirs  203.096.154.112 bytes libres

# %%
cd Completo
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Colombia\Completo

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Colombia\Completo
#
# 16/06/2026  19:50    <DIR>          .
# 16/06/2026  19:13    <DIR>          ..
# 16/06/2026  19:13         3.354.586 Colombia.csv
# 16/06/2026  19:13               712 FacebookAdLibraryReport_2026-06-13_CO_lifelong_locations.csv
# 16/06/2026  19:13             2.105 README.txt
# 16/06/2026  19:13    <DIR>          regions
#                3 archivos      3.357.403 bytes
#                3 dirs  203.096.072.192 bytes libres

# %%
import pandas as pd
df = pd.read_csv("Colombia.csv")

# Add a column with a fixed value
df["País"] = "Colombia"

# Save it back
df.to_csv("Colombia.csv", index=False)
df
# Out:
#                 Page ID                 Page name  \
# 0          241499431662            Fico Gutiérrez
# 1           95972290770             Gustavo Petro
# 2      1482897701997453           Paloma Valencia
# 3       257003761107098      Miguel Uribe Londoño
# 4       108379099286148  Alcaldía Mayor de Bogotá
# ...                 ...                       ...
# 44173   164565810073133                 DoubleTop
# 44174   111638323856452                  Be Welly
# 44175   133405343179092                  Baydream
# 44176  1757418337889277      Cooperativa Credi Ya
# 44177      185139171667              Daymond John
#
#                                Disclaimer Amount spent (COP)  \
# 0                      Federico Gutierrez         2408570714
# 1                           GUSTAVO PETRO         2130698135
# 2                         Paloma Valencia         1477639091
# 3                            Miguel Uribe         1371013034
# ...

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Colombia

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1
#
# 16/06/2026  19:41    <DIR>          .
# 16/06/2026  15:34    <DIR>          ..
# 16/06/2026  16:11    <DIR>          Argentina
# 16/06/2026  19:11    <DIR>          Bolivia
# 16/06/2026  18:34    <DIR>          Brazil
# 16/06/2026  19:00    <DIR>          Chile
# 16/06/2026  19:13    <DIR>          Colombia
# 16/06/2026  19:15    <DIR>          Ecuador
# 16/06/2026  19:35    <DIR>          Guyana
# 16/06/2026  18:53    <DIR>          Paraguay
# 16/06/2026  19:03    <DIR>          Per£
# 16/06/2026  19:41    <DIR>          Surinam
# 16/06/2026  18:45    <DIR>          Uruguay
# 16/06/2026  19:17    <DIR>          Venezuela
#                0 archivos              0 bytes
#               14 dirs  203.086.258.176 bytes libres

# %%
cd Ecuador
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Ecuador

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Ecuador
#
# 16/06/2026  19:15    <DIR>          .
# 16/06/2026  19:41    <DIR>          ..
# 16/06/2026  19:50    <DIR>          Completo
#                0 archivos              0 bytes
#                3 dirs  203.083.354.112 bytes libres

# %%
cd Completo
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Ecuador\Completo

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Ecuador\Completo
#
# 16/06/2026  19:50    <DIR>          .
# 16/06/2026  19:15    <DIR>          ..
# 16/06/2026  19:15         1.763.215 Ecuador.csv
# 16/06/2026  19:15               682 FacebookAdLibraryReport_2026-06-13_EC_lifelong_locations.csv
# 16/06/2026  19:15             2.105 README.txt
# 16/06/2026  19:15    <DIR>          regions
#                3 archivos      1.766.002 bytes
#                3 dirs  203.083.223.040 bytes libres

# %%
import pandas as pd
df = pd.read_csv("Ecuador.csv")

# Add a column with a fixed value
df["País"] = "Ecuador"

# Save it back
df.to_csv("Ecuador.csv", index=False)
df
# Out:
#                Page ID                                     Page name  \
# 0      115012276965624                            Daniel Noboa  Azin
# 1      339660569555689                        Presidencia de Ecuador
# 2      101275684769428                                Luisa González
# 3      129803967052432        Consejo Nacional Electoral del Ecuador
# 4      401049006603015                               Guillermo Lasso
# ...                ...                                           ...
# 22798  196386703560872                                 Coeducaciendo
# 22799  583477448472521                           Ocean Blue Dinghies
# 22800  176031462779495                                          海峽導報
# 22801  282449449330253  D-mighty Printing PRESS. Igbo-ora, Oyo State
# 22802  737034646151947                        Kitchen & Living Tools
#
#                                    Disclaimer Amount spent (USD)  \
# 0                           Daniel Noboa Azin            2649246
# ...

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Ecuador

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1
#
# 16/06/2026  19:41    <DIR>          .
# 16/06/2026  15:34    <DIR>          ..
# 16/06/2026  16:11    <DIR>          Argentina
# 16/06/2026  19:11    <DIR>          Bolivia
# 16/06/2026  18:34    <DIR>          Brazil
# 16/06/2026  19:00    <DIR>          Chile
# 16/06/2026  19:13    <DIR>          Colombia
# 16/06/2026  19:15    <DIR>          Ecuador
# 16/06/2026  19:35    <DIR>          Guyana
# 16/06/2026  18:53    <DIR>          Paraguay
# 16/06/2026  19:03    <DIR>          Per£
# 16/06/2026  19:41    <DIR>          Surinam
# 16/06/2026  18:45    <DIR>          Uruguay
# 16/06/2026  19:17    <DIR>          Venezuela
#                0 archivos              0 bytes
#               14 dirs  203.079.962.624 bytes libres

# %%
cd Guyana
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Guyana

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Guyana
#
# 16/06/2026  19:35    <DIR>          .
# 16/06/2026  19:41    <DIR>          ..
# 16/06/2026  19:51    <DIR>          Completo
#                0 archivos              0 bytes
#                3 dirs  203.077.013.504 bytes libres

# %%
cd Completo
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Guyana\Completo

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Guyana\Completo
#
# 16/06/2026  19:51    <DIR>          .
# 16/06/2026  19:35    <DIR>          ..
# 16/06/2026  19:36               303 FacebookAdLibraryReport_2026-06-13_GY_lifelong_locations.csv
# 16/06/2026  19:36           493.300 Guyana.csv
# 16/06/2026  19:36             2.105 README.txt
# 16/06/2026  19:36    <DIR>          regions
#                3 archivos        495.708 bytes
#                3 dirs  203.068.063.744 bytes libres

# %%
import pandas as pd
df = pd.read_csv("Guyana.csv")

# Add a column with a fixed value
df["País"] = "Guyana"

# Save it back
df.to_csv("Guyana.csv", index=False)
df
# Out:
#               Page ID                        Page name  \
# 0     110601870576593           Guardians of Democracy
# 1        114653269155  Peoples Progressive Party/Civic
# 2     589886034217808                   PPPC Fans Club
# 3     104115922089540        Through the looking glass
# 4     865157226909370      Mohabir Anil Nandlall SC MP
# ...               ...                              ...
# 6240  521600091028761  Learna AI: English Learning App
# 6241  213070302133913                 Rhics Technology
# 6242  186603945318526               The real Sean John
# 6243  155460521146066                   RFI Tiếng Việt
# 6244  109629048093692                 Pepe Misterio MX
#
#                               Disclaimer Amount spent (USD)  \
# 0                 Guardians of Democracy              19154
# 1        Peoples Progressive Party/Civic               7120
# 2                         PPPC Fans Club               5126
# ...

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Guyana

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1
#
# 16/06/2026  19:41    <DIR>          .
# 16/06/2026  15:34    <DIR>          ..
# 16/06/2026  16:11    <DIR>          Argentina
# 16/06/2026  19:11    <DIR>          Bolivia
# 16/06/2026  18:34    <DIR>          Brazil
# 16/06/2026  19:00    <DIR>          Chile
# 16/06/2026  19:13    <DIR>          Colombia
# 16/06/2026  19:15    <DIR>          Ecuador
# 16/06/2026  19:35    <DIR>          Guyana
# 16/06/2026  18:53    <DIR>          Paraguay
# 16/06/2026  19:03    <DIR>          Per£
# 16/06/2026  19:41    <DIR>          Surinam
# 16/06/2026  18:45    <DIR>          Uruguay
# 16/06/2026  19:17    <DIR>          Venezuela
#                0 archivos              0 bytes
#               14 dirs  203.056.181.248 bytes libres

# %%
cd Paraguay
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Paraguay

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Paraguay
#
# 16/06/2026  18:53    <DIR>          .
# 16/06/2026  19:41    <DIR>          ..
# 16/06/2026  19:51    <DIR>          Completo
#                0 archivos              0 bytes
#                3 dirs  203.053.203.456 bytes libres

# %%
cd Completo
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Paraguay\Completo

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Paraguay\Completo
#
# 16/06/2026  19:51    <DIR>          .
# 16/06/2026  18:53    <DIR>          ..
# 16/06/2026  18:53               630 FacebookAdLibraryReport_2026-06-13_PY_lifelong_locations.csv
# 16/06/2026  18:53           967.387 Paraguay.csv
# 16/06/2026  18:53             2.105 README.txt
#                3 archivos        970.122 bytes
#                2 dirs  203.054.354.432 bytes libres

# %%
import pandas as pd
df = pd.read_csv("Paraguay.csv")

# Add a column with a fixed value
df["País"] = "Paraguay"

# Save it back
df.to_csv("Paraguay.csv", index=False)
df
# Out:
#                 Page ID                                 Page name  \
# 0      1468570519872644                             Santiago Peña
# 1       138282352917817  Presidencia de la República del Paraguay
# 2       225715453952129                          Central Noticias
# 3      1151984808290856                             Hugo Portillo
# 4       325540631525675                               En La Tecla
# ...                 ...                                       ...
# 12536   133802223457730                           ECLT Foundation
# 12537      264784521318        Arjun Dhingra, Mortgage Consultant
# 12538   494890083713822                          New Me  New Year
# 12539   105825945425760                               Yon Stories
# 12540   443243126123743                       Electionscount.info
#
#                                      Disclaimer Amount spent (PYG)  \
# 0                                      PRANA SA          832457800
# ...

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Paraguay

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1
#
# 16/06/2026  19:41    <DIR>          .
# 16/06/2026  15:34    <DIR>          ..
# 16/06/2026  16:11    <DIR>          Argentina
# 16/06/2026  19:11    <DIR>          Bolivia
# 16/06/2026  18:34    <DIR>          Brazil
# 16/06/2026  19:00    <DIR>          Chile
# 16/06/2026  19:13    <DIR>          Colombia
# 16/06/2026  19:15    <DIR>          Ecuador
# 16/06/2026  19:35    <DIR>          Guyana
# 16/06/2026  18:53    <DIR>          Paraguay
# 16/06/2026  19:03    <DIR>          Per£
# 16/06/2026  19:41    <DIR>          Surinam
# 16/06/2026  18:45    <DIR>          Uruguay
# 16/06/2026  19:17    <DIR>          Venezuela
#                0 archivos              0 bytes
#               14 dirs  203.045.326.848 bytes libres

# %%
cd Perú
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Perú

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Per£
#
# 16/06/2026  19:03    <DIR>          .
# 16/06/2026  19:41    <DIR>          ..
# 16/06/2026  19:51    <DIR>          Completo
#                0 archivos              0 bytes
#                3 dirs  203.042.500.608 bytes libres

# %%
cd Completo
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Perú\Completo

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Per£\Completo
#
# 16/06/2026  19:51    <DIR>          .
# 16/06/2026  19:03    <DIR>          ..
# 16/06/2026  19:03               609 FacebookAdLibraryReport_2026-06-13_PE_lifelong_locations.csv
# 16/06/2026  19:03         2.181.250 Per£.csv
# 16/06/2026  19:03             2.105 README.txt
# 16/06/2026  19:03    <DIR>          regions
#                3 archivos      2.183.964 bytes
#                3 dirs  203.039.502.336 bytes libres

# %%
import pandas as pd
df = pd.read_csv("Perú.csv")

# Add a column with a fixed value
df["País"] = "Perú"

# Save it back
df.to_csv("Perú.csv", index=False)
df
# Out:
#                Page ID                             Page name  \
# 0      101665683225827          José Luna Gálvez - Pepe Luna
# 1      101665683225827          José Luna Gálvez - Pepe Luna
# 2      101665683225827          José Luna Gálvez - Pepe Luna
# 3      317113615022843                           César Acuña
# 4      566970220173238                          Podemos Perú
# ...                ...                                   ...
# 27809     183463793013                          WordzPerfect
# 27810  113219865026108                       Mons. Salvatore
# 27811  196847517071886  Centro Venezolano para la Democracia
# 27812  100913549609447                        Balanced Bites
# 27813  101835809118348                          Pura Harmony
#
#                                Disclaimer Amount spent (PEN)  \
# 0            José Luna Gálvez - Pepe Luna            3937404
# 1           Mery Nataly Gonzales Enriquez            3358400
# ...

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Perú

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1
#
# 16/06/2026  19:41    <DIR>          .
# 16/06/2026  15:34    <DIR>          ..
# 16/06/2026  16:11    <DIR>          Argentina
# 16/06/2026  19:11    <DIR>          Bolivia
# 16/06/2026  18:34    <DIR>          Brazil
# 16/06/2026  19:00    <DIR>          Chile
# 16/06/2026  19:13    <DIR>          Colombia
# 16/06/2026  19:15    <DIR>          Ecuador
# 16/06/2026  19:35    <DIR>          Guyana
# 16/06/2026  18:53    <DIR>          Paraguay
# 16/06/2026  19:03    <DIR>          Per£
# 16/06/2026  19:41    <DIR>          Surinam
# 16/06/2026  18:45    <DIR>          Uruguay
# 16/06/2026  19:17    <DIR>          Venezuela
#                0 archivos              0 bytes
#               14 dirs  203.033.399.296 bytes libres

# %%
cd Surinam
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Surinam

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Surinam
#
# 16/06/2026  19:41    <DIR>          .
# 16/06/2026  19:41    <DIR>          ..
# 16/06/2026  19:51    <DIR>          Completo
#                0 archivos              0 bytes
#                3 dirs  203.034.304.512 bytes libres

# %%
cd Completo
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Surinam\Completo

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Surinam\Completo
#
# 16/06/2026  19:51    <DIR>          .
# 16/06/2026  19:41    <DIR>          ..
# 16/06/2026  19:41               283 FacebookAdLibraryReport_2026-06-13_SR_lifelong_locations.csv
# 16/06/2026  19:41             2.105 README.txt
# 16/06/2026  19:41    <DIR>          regions
# 16/06/2026  19:41           472.785 Surinam.csv
#                3 archivos        475.173 bytes
#                3 dirs  203.031.171.072 bytes libres

# %%
import pandas as pd
df = pd.read_csv("Surinam.csv")

# Add a column with a fixed value
df["País"] = "Surinam"

# Save it back
df.to_csv("Surinam.csv", index=False)
df
# Out:
#                Page ID                                  Page name  \
# 0      208654225842653  Vooruitstrevende Hervormings Partij - VHP
# 1     1419329625039931                Krishna Hussainali Mathoera
# 2     1618337698388191                       Michael Ashwin Adhin
# 3      150628755693747                            Pertjajah Luhur
# 4      385027021350812                APP- Arena Politieke Partij
# ...                ...                                        ...
# 6006   111071828580081                                      Wsp25
# 6007   101339572785677                        China Meets Estonia
# 6008   907478086066710                              The Stephen 3
# 6009   102538795925802                              Solo_tech_VPN
# 6010  1465646276779035                        Los Secretos Judíos
#
#                                      Disclaimer Amount spent (USD)  \
# 0     Vooruitstrevende Hervormings Partij - VHP              15579
# ...

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Surinam

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1
#
# 16/06/2026  19:41    <DIR>          .
# 16/06/2026  15:34    <DIR>          ..
# 16/06/2026  16:11    <DIR>          Argentina
# 16/06/2026  19:11    <DIR>          Bolivia
# 16/06/2026  18:34    <DIR>          Brazil
# 16/06/2026  19:00    <DIR>          Chile
# 16/06/2026  19:13    <DIR>          Colombia
# 16/06/2026  19:15    <DIR>          Ecuador
# 16/06/2026  19:35    <DIR>          Guyana
# 16/06/2026  18:53    <DIR>          Paraguay
# 16/06/2026  19:03    <DIR>          Per£
# 16/06/2026  19:41    <DIR>          Surinam
# 16/06/2026  18:45    <DIR>          Uruguay
# 16/06/2026  19:17    <DIR>          Venezuela
#                0 archivos              0 bytes
#               14 dirs  203.023.724.544 bytes libres

# %%
cd Uruguay
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Uruguay

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Uruguay
#
# 16/06/2026  18:45    <DIR>          .
# 16/06/2026  19:41    <DIR>          ..
# 16/06/2026  19:51    <DIR>          Completo
#                0 archivos              0 bytes
#                3 dirs  203.020.763.136 bytes libres

# %%
cd Completo
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Uruguay\Completo

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Uruguay\Completo
#
# 16/06/2026  19:51    <DIR>          .
# 16/06/2026  18:45    <DIR>          ..
# 16/06/2026  18:45               589 FacebookAdLibraryReport_2026-06-13_UY_lifelong_locations.csv
# 16/06/2026  18:45             2.105 README.txt
# 16/06/2026  18:45    <DIR>          regions
# 16/06/2026  18:45           826.260 Uruguay.csv
#                3 archivos        828.954 bytes
#                3 dirs  203.020.431.360 bytes libres

# %%
import pandas as pd
df = pd.read_csv("Uruguay.csv")

# Add a column with a fixed value
df["País"] = "Uruguay"

# Save it back
df.to_csv("Uruguay.csv", index=False)
df
# Out:
#                 Page ID                      Page name  \
# 0      2229936167288652                   Juan Sartori
# 1       262275326972703        Yamandú Orsi Presidente
# 2       329759403562013  Andrés Ojeda Unir para Crecer
# 3       186890914798005                 Alvaro Delgado
# 4       100361409150499                 Seregnistas 95
# ...                 ...                            ...
# 10650  1881543645439590     Tech It Out with Yang Zhao
# 10651   106654065081743              MKAKKOii- 0830- 4
# 10652   907478086066710                  The Stephen 3
# 10653   102075811887387         Chocolate.com - Images
# 10654                 0      Instagram User 7671673101
#
#                                  Disclaimer Amount spent (UYU)  \
# 0                       Equipo Juan Sartori            4591456
# 1                   Yamandú Orsi Presidente            4579656
# 2                   Andrés Ojeda Presidente            3962283
# ...

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Uruguay

# %%
cd ..
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1
#
# 16/06/2026  19:41    <DIR>          .
# 16/06/2026  15:34    <DIR>          ..
# 16/06/2026  16:11    <DIR>          Argentina
# 16/06/2026  19:11    <DIR>          Bolivia
# 16/06/2026  18:34    <DIR>          Brazil
# 16/06/2026  19:00    <DIR>          Chile
# 16/06/2026  19:13    <DIR>          Colombia
# 16/06/2026  19:15    <DIR>          Ecuador
# 16/06/2026  19:35    <DIR>          Guyana
# 16/06/2026  18:53    <DIR>          Paraguay
# 16/06/2026  19:03    <DIR>          Per£
# 16/06/2026  19:41    <DIR>          Surinam
# 16/06/2026  18:45    <DIR>          Uruguay
# 16/06/2026  19:17    <DIR>          Venezuela
#                0 archivos              0 bytes
#               14 dirs  202.982.445.056 bytes libres

# %%
cd Venezuela
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Venezuela

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Venezuela
#
# 16/06/2026  19:17    <DIR>          .
# 16/06/2026  19:41    <DIR>          ..
# 16/06/2026  19:52    <DIR>          Completo
#                0 archivos              0 bytes
#                3 dirs  202.982.440.960 bytes libres

# %%
cd Completo
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Venezuela\Completo

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1\Venezuela\Completo
#
# 16/06/2026  19:52    <DIR>          .
# 16/06/2026  19:17    <DIR>          ..
# 16/06/2026  19:17               552 FacebookAdLibraryReport_2026-06-13_VE_lifelong_locations.csv
# 16/06/2026  19:17             2.105 README.txt
# 16/06/2026  19:17    <DIR>          regions
# 16/06/2026  19:17           642.685 Venezuela.csv
#                3 archivos        645.342 bytes
#                3 dirs  202.979.733.504 bytes libres

# %%
import pandas as pd
df = pd.read_csv("Venezuela.csv")

# Add a column with a fixed value
df["País"] = "Venezuela"

# Save it back
df.to_csv("Venezuela.csv", index=False)
df
# Out:
#                Page ID                                 Page name  \
# 0      114061055053463                                Ojo pelado
# 1      110796658935065                            Antonio Ecarri
# 2      333566379844819                         VE Hasta el Final
# 3      258138027555902                           Javier Bertucci
# 4         328207698997                           David Uzcátegui
# ...                ...                                       ...
# 8189   111812808446141                          Efraín Hernández
# 8190   113512245171403                             Lemon squeezy
# 8191   101207769235713  Zucami Poultry Equipment - International
# 8192   261822930353726                        AI Pixel Art-US 03
# 8193  1580082582270698               General Auditing Commission
#
#                               Disclaimer Amount spent (VEF)  \
# 0             an advertiser in Venezuela        31386615416
# 1             an advertiser in Venezuela        24459550286
# ...

# %%
cd ..
# Out:
# C:\Users

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users
#
# 22/12/2025  20:40    <DIR>          .
# 17/06/2026  08:48    <DIR>          igrimaldi
# 15/06/2026  19:01    <DIR>          Public
# 24/12/2025  09:39    <DIR>          rbrom
# 07/09/2025  22:27    <DIR>          soporte
#                0 archivos              0 bytes
#                5 dirs  202.021.699.584 bytes libres

# %%
cd igrimaldi
# Out:
# C:\Users\igrimaldi

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi
#
# 17/06/2026  08:48    <DIR>          .
# 22/12/2025  20:40    <DIR>          ..
# 01/06/2026  19:59    <DIR>          .config
# 17/06/2026  01:45    <DIR>          .ipynb_checkpoints
# 05/06/2026  13:41    <DIR>          .ipython
# 05/06/2026  13:38    <DIR>          .jupyter
# 11/06/2026  16:07    <DIR>          .matplotlib
# 09/06/2026  22:43    <DIR>          .ms-ad
# 01/06/2026  21:47    <DIR>          .venvs
# 01/06/2026  19:34    <DIR>          .vscode
# 01/06/2026  19:34    <DIR>          .vscode-shared
# 03/06/2026  12:34               206 .wget-hsts
# 10/06/2026  00:29             9.092 01-Geocoding with APIs-1.ipynb
# 10/06/2026  17:49            47.079 03-Last FM API (Music).ipynb
# 08/06/2026  20:49               271 addresses.csv
# 09/06/2026  02:40               303 addresses-geocoded.csv
# 08/06/2026  14:07           200.899 bird.ipynb
# ...

# %%
cd Lede Program
# Out:
# C:\Users\igrimaldi\Lede Program

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program
#
# 16/06/2026  15:34    <DIR>          .
# 17/06/2026  08:48    <DIR>          ..
# 15/06/2026  10:18    <DIR>          .ipynb_checkpoints
# 10/06/2026  11:04    <DIR>          __MACOSX
# 10/06/2026  11:04               764 01-pandas basics.ipynb
# 10/06/2026  11:04           974.401 06-classwork.zip
# 12/06/2026  11:06            43.444 07-classwork.zip
# 10/06/2026  11:04               125 continent_facts.csv
# 10/06/2026  11:04             8.570 countries.csv
# 15/06/2026  10:20    <DIR>          Data Cleaning
# 10/06/2026  11:04    <DIR>          encoding
# 12/06/2026  11:06    <DIR>          HomeworkClass6
# 10/06/2026  15:35           156.468 IN CLASS COMPLETED Class 06.ipynb
# 27/05/2026  18:01           230.218 Listado de CBU.xlsx
# 17/06/2026  19:23    <DIR>          Project 1
# 17/06/2026  17:49    <DIR>          Scraping
# ...

# %%
cd Project 1
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1

# %%
ls
# Out:
#  El volumen de la unidad C es OSDisk
#  El n£mero de serie del volumen es: 6CEF-3194
#
#  Directorio de C:\Users\igrimaldi\Lede Program\Project 1
#
# 17/06/2026  19:23    <DIR>          .
# 16/06/2026  15:34    <DIR>          ..
# 16/06/2026  16:11    <DIR>          Argentina
# 16/06/2026  19:11    <DIR>          Bolivia
# 16/06/2026  18:34    <DIR>          Brazil
# 16/06/2026  19:00    <DIR>          Chile
# 16/06/2026  19:13    <DIR>          Colombia
# 16/06/2026  19:15    <DIR>          Ecuador
# 16/06/2026  19:35    <DIR>          Guyana
# 16/06/2026  18:53    <DIR>          Paraguay
# 16/06/2026  19:03    <DIR>          Per£
# 16/06/2026  19:41    <DIR>          Surinam
# 17/06/2026  19:54    <DIR>          Todos
# 16/06/2026  18:45    <DIR>          Uruguay
# 16/06/2026  19:17    <DIR>          Venezuela
#                0 archivos              0 bytes
#               15 dirs  202.041.593.856 bytes libres

# %%
cd Todos
# Out:
# C:\Users\igrimaldi\Lede Program\Project 1\Todos

# %%
import pandas as pd

# %%
DATA_DIR = "C:\Users\igrimaldi\Lede Program\Project 1\Todos"  

FILES = ["Argentina.csv", "Bolivia.csv", "Brazil.csv", "Chile.csv",
    "Colombia.csv", "Ecuador.csv", "Guyana.csv", "Paraguay.csv",
    "Perú.csv", "Surinam.csv", "Uruguay.csv", "Venezuela.csv"]

RATES = {"ARS": 1461.0, "BOB": 7.09, "BRL": 5.20, "CLP": 904.15,
    "COP": 3545.23, "PEN": 3.44, "PYG": 6244.29, "UYU": 40.97,
    "VEF": 608.71, "USD": 1.0}
# Out:
#   Cell In[11], line 1
#     DATA_DIR = "C:\Users\igrimaldi\Lede Program\Project 1\Todos"
#                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
